# %% [markdown]
# # Importing packages

# %%
import pandas as pd
import numpy as np
import os
import re
from pathlib import Path
from bokeh.io import output_notebook
output_notebook()
bokeh_width, bokeh_height = 500,400
pd.options.mode.chained_assignment = None  # default='warn'
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load data

# %%
p = Path('.')
data = pd.read_csv("Non-Fatal_Shootings_-_2013.csv")

# %% [markdown]
# # Remove duplicates column

# %%
data.drop_duplicates(inplace = True)

# %%
data
# Out:
#     Type        Date  Time                              Location       City  \
# 0    NFS  08/27/2013  1428  Unknown location in Baltimore County    Unknown
# 1    NFS  01/10/2013  1040                      2000 Hoffman St.  Baltimore
# 2    NFS  12/18/2013  1826                      3200 Brendan Ave  Baltimore
# 3    NFS  02/20/2013  2359                      11610 Citrine Ct   Glendale
# 4    NFS  10/13/2013   100                          214 Green St  Fruitland
# ..   ...         ...   ...                                   ...        ...
# 678  NFS  12/04/2013  2230                      3224 Belmont Ave  Baltimore
# 679  NFS  12/05/2013  2137                     3500 Leverton Ave  Baltimore
# 680  NFS  10/17/2013  2311                     1600 Northgate Rd  Baltimore
# 681  NFS  04/18/2013  2055                   400 N. Robinson St.  Baltimore
# 682  NFS  12/17/2013  2149                  4506 Westchester Ave  Baltimore
#
#               County    Zip                                            Geocode
# 0          Baltimore      0    Unknown location in Baltimore County\nUnknown 0
# 1        Balto. City  21213  2000 Hoffman St.\nBaltimore 21213\n(39.3066183...
# 2        Balto. City  21213  3200 Brendan Ave\nBaltimore 21213\n(39.3222040...
# 3    Prince George's  20769  11610 Citrine Ct\nGlendale 20769\n(38.95854285...
# 4           Wicomico  21826  214 Green St\nFruitland 21826\n(38.31945272500...
# ..               ...    ...                                                ...
# 678      Balto. City  21216  3224 Belmont Ave\nBaltimore 21216\n(39.3024966...
# 679      Balto. City  21224  3500 Leverton Ave\nBaltimore 21224\n(39.291848...
# 680      Balto. City  21218  1600 Northgate Rd\nBaltimore 21218\n(39.345078...
# 681      Balto. City  21224  400 N. Robinson St.\nBaltimore 21224\n(39.2960...
# 682      Balto. City  21216  4506 Westchester Ave\nBaltimore 21216\n(39.318...
#
# [595 rows x 8 columns]

# %% [markdown]
# # Check empty lines

# %%
data.isnull().sum() #data.isna().sum()
# Out:
# Type        0
# Date        0
# Time        0
# Location    0
# City        0
# County      0
# Zip         0
# Geocode     0
# dtype: int64

# %%
data.reset_index(inplace = True)

# %%
data.drop(columns = ["index"], inplace = True)
data
# Out:
#     Type        Date  Time                              Location       City  \
# 0    NFS  08/27/2013  1428  Unknown location in Baltimore County    Unknown
# 1    NFS  01/10/2013  1040                      2000 Hoffman St.  Baltimore
# 2    NFS  12/18/2013  1826                      3200 Brendan Ave  Baltimore
# 3    NFS  02/20/2013  2359                      11610 Citrine Ct   Glendale
# 4    NFS  10/13/2013   100                          214 Green St  Fruitland
# ..   ...         ...   ...                                   ...        ...
# 590  NFS  12/04/2013  2230                      3224 Belmont Ave  Baltimore
# 591  NFS  12/05/2013  2137                     3500 Leverton Ave  Baltimore
# 592  NFS  10/17/2013  2311                     1600 Northgate Rd  Baltimore
# 593  NFS  04/18/2013  2055                   400 N. Robinson St.  Baltimore
# 594  NFS  12/17/2013  2149                  4506 Westchester Ave  Baltimore
#
#               County    Zip                                            Geocode
# 0          Baltimore      0    Unknown location in Baltimore County\nUnknown 0
# 1        Balto. City  21213  2000 Hoffman St.\nBaltimore 21213\n(39.3066183...
# 2        Balto. City  21213  3200 Brendan Ave\nBaltimore 21213\n(39.3222040...
# 3    Prince George's  20769  11610 Citrine Ct\nGlendale 20769\n(38.95854285...
# 4           Wicomico  21826  214 Green St\nFruitland 21826\n(38.31945272500...
# ..               ...    ...                                                ...
# 590      Balto. City  21216  3224 Belmont Ave\nBaltimore 21216\n(39.3024966...
# 591      Balto. City  21224  3500 Leverton Ave\nBaltimore 21224\n(39.291848...
# 592      Balto. City  21218  1600 Northgate Rd\nBaltimore 21218\n(39.345078...
# 593      Balto. City  21224  400 N. Robinson St.\nBaltimore 21224\n(39.2960...
# 594      Balto. City  21216  4506 Westchester Ave\nBaltimore 21216\n(39.318...
#
# [595 rows x 8 columns]

# %%
data.dtypes
# Out:
# Type        object
# Date        object
# Time         int64
# Location    object
# City        object
# County      object
# Zip          int64
# Geocode     object
# dtype: object

# %% [markdown]
# # Verify Date and Time and create one column with Date type

# %%
data["datelong"] = data.Date.apply(lambda x: len(str(x)))

# %%
data["timelong"] = data.Time.apply(lambda x: len(str(x)))

# %%
data.Time[(data['timelong'] != 4)]
# Out:
# 4      100
# 6        3
# 7      336
# 9      134
# 11     144
#       ...
# 564     28
# 568    116
# 571    130
# 573    338
# 581      0
# Name: Time, Length: 203, dtype: int64

# %%
data.Time = data.Time.apply(str)
data.dtypes
# Out:
# Type        object
# Date        object
# Time        object
# Location    object
# City        object
# County      object
# Zip          int64
# Geocode     object
# datelong     int64
# timelong     int64
# dtype: object

# %%
data["NewTime"]=data.Time

# %%
data
# Out:
#     Type        Date  Time                              Location       City  \
# 0    NFS  08/27/2013  1428  Unknown location in Baltimore County    Unknown
# 1    NFS  01/10/2013  1040                      2000 Hoffman St.  Baltimore
# 2    NFS  12/18/2013  1826                      3200 Brendan Ave  Baltimore
# 3    NFS  02/20/2013  2359                      11610 Citrine Ct   Glendale
# 4    NFS  10/13/2013   100                          214 Green St  Fruitland
# ..   ...         ...   ...                                   ...        ...
# 590  NFS  12/04/2013  2230                      3224 Belmont Ave  Baltimore
# 591  NFS  12/05/2013  2137                     3500 Leverton Ave  Baltimore
# 592  NFS  10/17/2013  2311                     1600 Northgate Rd  Baltimore
# 593  NFS  04/18/2013  2055                   400 N. Robinson St.  Baltimore
# 594  NFS  12/17/2013  2149                  4506 Westchester Ave  Baltimore
#
#               County    Zip  \
# 0          Baltimore      0
# 1        Balto. City  21213
# 2        Balto. City  21213
# 3    Prince George's  20769
# 4           Wicomico  21826
# ..               ...    ...
# 590      Balto. City  21216
# 591      Balto. City  21224
# 592      Balto. City  21218
# 593      Balto. City  21224
# 594      Balto. City  21216
#
#                                                Geocode  datelong  timelong  \
# 0      Unknown location in Baltimore County\nUnknown 0        10         4
# 1    2000 Hoffman St.\nBaltimore 21213\n(39.3066183...        10         4
# 2    3200 Brendan Ave\nBaltimore 21213\n(39.3222040...        10         4
# 3    11610 Citrine Ct\nGlendale 20769\n(38.95854285...        10         4
# 4    214 Green St\nFruitland 21826\n(38.31945272500...        10         3
# ..                                                 ...       ...       ...
# 590  3224 Belmont Ave\nBaltimore 21216\n(39.3024966...        10         4
# 591  3500 Leverton Ave\nBaltimore 21224\n(39.291848...        10         4
# 592  1600 Northgate Rd\nBaltimore 21218\n(39.345078...        10         4
# 593  400 N. Robinson St.\nBaltimore 21224\n(39.2960...        10         4
# 594  4506 Westchester Ave\nBaltimore 21216\n(39.318...        10         4
#
#     NewTime
# 0      1428
# 1      1040
# 2      1826
# 3      2359
# 4       100
# ..      ...
# 590    2230
# 591    2137
# 592    2311
# 593    2055
# 594    2149
#
# [595 rows x 11 columns]

# %%
(data['NewTime'].str.len()<4).sum()
# Out:
# 203

# %%
nb_of_val=(data['NewTime'].str.len()<4).sum()
while(nb_of_val!=0):
    data['NewTime'] = data.NewTime.apply(lambda s: '0' + s if len(s) < 4 else s) 
    nb_of_val=(data['NewTime'].str.len()<4).sum()
    print(nb_of_val)
# Out:
# 57
# 21
# 0

# %%
data[:25]
# Out:
#                     Type        Date  Time  \
# 0                    NFS  08/27/2013  1428
# 1                    NFS  01/10/2013  1040
# 2                    NFS  12/18/2013  1826
# 3                    NFS  02/20/2013  2359
# 4                    NFS  10/13/2013   100
# 5                    NFS  05/23/2013  2222
# 6                    NFS  04/19/2013     3
# 7                    NFS  02/02/2013   336
# 8                    NFS  09/19/2013  2235
# 9                    NFS  10/11/2013   134
# 10  NFS - self inflicted  12/24/2013  1631
# 11                   NFS  07/31/2013   144
# 12                   NFS  11/24/2013    30
# 13                   NFS  11/13/2013  2207
# 14                   NFS  12/02/2013   144
# 15                   NFS  06/22/2013   127
# 16  NFS - self inflicted  02/12/2013   915
# 17                   NFS  09/08/2013   242
# 18                   NFS  05/20/2013  1700
# 19                   NFS  11/25/2013   153
# 20                   NFS  08/19/2013   330
# 21                   NFS  08/18/2013  2038
# 22                   NFS  09/25/2013  1850
# 23                   NFS  03/21/2013  1500
# 24                   NFS  09/08/2013   320
#
#                                 Location            City           County  \
# 0   Unknown location in Baltimore County         Unknown        Baltimore
# 1                       2000 Hoffman St.       Baltimore      Balto. City
# 2                       3200 Brendan Ave       Baltimore      Balto. City
# 3                       11610 Citrine Ct        Glendale  Prince George's
# 4                           214 Green St       Fruitland         Wicomico
# 5                        1723 Hollins St       Baltimore      Balto. City
# 6                104 Back River Neck Rd.           Essex        Baltimore
# 7                  3411 Reisterstown Rd.       Baltimore      Balto. City
# 8                          5321 85th Ave  New Carrollton  Prince George's
# 9                            100 Penn St       Baltimore      Balto. City
# 10                    27331 Birchwood Ct  Mechanicsville       St. Mary's
# 13         4    2207
# 14         3    0144
# 15         3    0127
# 16         3    0915
# 17         3    0242
# 18         4    1700
# 19         3    0153
# 20         3    0330
# 21         4    2038
# 22         4    1850
# 23         4    1500
# 24         3    0320

# %%
data["DateNew"] = data["Date"].astype(str) + " " + data["NewTime"].astype(str)

# %%
data["DateAndTime"] = pd.to_datetime(data["DateNew"])

# %%
data.Type.value_counts()
# Out:
# NFS                     554
# NFS - self inflicted     41
# Name: Type, dtype: int64

# %%
dataplot = data[["Type","Geocode", "DateAndTime"]]

# %%
dataplot.Type.value_counts()
# Out:
# NFS                     554
# NFS - self inflicted     41
# Name: Type, dtype: int64

# %%
dataplot["Type"].replace("NFS - self inflicted", "SIS", inplace= True)

# %%
dataplot.Type.value_counts()
# Out:
# NFS    554
# SIS     41
# Name: Type, dtype: int64

# %%
dataplot["latitude"] = dataplot.Geocode.apply(lambda x: re.findall("\((.*\d+\.\d+),", x))

# %%
dataplot["latitude"] = dataplot.latitude.apply(lambda x: x[0] if len(x)>0 else "NA")

# %%
dataplot.drop(dataplot.index[dataplot["latitude"] == "NA"], inplace = True)

# %%
dataplot["longitude"] = dataplot.Geocode.apply(lambda x: re.findall(",(.*\d+\.\d+)\)", x))

# %%
dataplot["longitude"] = dataplot.longitude.apply(lambda x: x[0] if len(x)>0 else "NA")

# %%
dataplot.drop(dataplot.index[dataplot["longitude"] == "NA"], inplace = True)

# %%
dataplot
# Out:
#     Type                                            Geocode  \
# 1    NFS  2000 Hoffman St.\nBaltimore 21213\n(39.3066183...
# 2    NFS  3200 Brendan Ave\nBaltimore 21213\n(39.3222040...
# 3    NFS  11610 Citrine Ct\nGlendale 20769\n(38.95854285...
# 4    NFS  214 Green St\nFruitland 21826\n(38.31945272500...
# 5    NFS  1723 Hollins St\nBaltimore 21223\n(39.28726344...
# ..   ...                                                ...
# 590  NFS  3224 Belmont Ave\nBaltimore 21216\n(39.3024966...
# 591  NFS  3500 Leverton Ave\nBaltimore 21224\n(39.291848...
# 592  NFS  1600 Northgate Rd\nBaltimore 21218\n(39.345078...
# 593  NFS  400 N. Robinson St.\nBaltimore 21224\n(39.2960...
# 594  NFS  4506 Westchester Ave\nBaltimore 21216\n(39.318...
#
#             DateAndTime            latitude            longitude
# 1   2013-01-10 10:40:00   39.30661831800046   -76.58991166499965
# 2   2013-12-18 18:26:00   39.32220408100045   -76.56960269799964
# 3   2013-02-20 23:59:00   38.95854285100046   -76.80436895499963
# 4   2013-10-13 01:00:00  38.319452725000474   -75.61894715499966
# 5   2013-05-23 22:22:00   39.28726344000046   -76.64459895999966
# ..                  ...                 ...                  ...
# 590 2013-12-04 22:30:00   39.30249660600049   -76.67132267999966
# 591 2013-12-05 21:37:00  39.291848092000464   -76.56841794299964
# 592 2013-10-17 23:11:00  39.345078028000444   -76.58920992599963
# 593 2013-04-18 20:55:00   39.29609798400048   -76.57294546799966
# 594 2013-12-17 21:49:00   39.31821496700047   -76.69029205499965
#
# [594 rows x 5 columns]

# %%
dataplot.latitude = dataplot.latitude.apply(float)

# %%
lat_mean = np.mean(dataplot.latitude)

# %%
dataplot.longitude = dataplot.longitude.apply(float)

# %%
long_mean = np.mean(dataplot.longitude)

# %%
# import plotly.express as px
# fig = px.histogram(geo_df, x="geometry" )
# #fig = px.scatter(x=dataplot.longitude, y=dataplot.latitude)
# fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-01f82b412c67> in <module>
#       1 import plotly.express as px
# ----> 2 fig = px.histogram(geo_df, x="geometry" )
#       3 #fig = px.scatter(x=dataplot.longitude, y=dataplot.latitude)
#       4 fig.show()
#
# NameError: name 'geo_df' is not defined

# %%
#api_key = "AIzaSyCf95Md6-183KHEYwfg8tKP7H50wU3Qveo"

# %%
# from bokeh.io import show
# from bokeh.plotting import gmap
# from bokeh.models import GMapOptions

# def plot(lat, lng, zoom=10, map_type='roadmap'):
#     gmap_options = GMapOptions(lat=lat, lng=lng, 
#                                map_type=map_type, zoom=10)
#     p = gmap(api_key, gmap_options, title='Pays de Gex', 
#              width=800, height=800)
#     show(p)
#     return p

# %%
# p = plot(lat_mean, long_mean)
# Out:
#   <div class="bk-root" id="86094221-bf43-47ed-bdd3-9a3b37363def" data-root-id="1004"></div>

# %%
# def plot(lat, lng, zoom=10, map_type='roadmap'):
#     gmap_options = GMapOptions(lat=lat, lng=lng, 
#                                map_type=map_type, zoom=zoom)
#     p = gmap(api_key, gmap_options, title='Pays de Gex', 
#              width=800, height=800)
#     # attention, la longitude est en abscisse ;-)
#     center = p.circle([lng], [lat], size=10, alpha=0.5, color='red')
#     show(p)
#     return p

# %%
# p = plot(lat_mean, long_mean, map_type='terrain')
# Out:
#   <div class="bk-root" id="bd85560a-8894-4143-a79d-aecc28605660" data-root-id="1069"></div>

# %%
# from bokeh.models import ColumnDataSource
# from bokeh.transform import linear_cmap
# from bokeh.palettes import Plasma256 as palette
# from bokeh.models import ColorBar

# def plot(lat, lng, zoom=10, map_type='roadmap'):
#     gmap_options = GMapOptions(lat=lat, lng=lng, 
#                                map_type=map_type, zoom=zoom)
#     p = gmap(api_key, gmap_options, title='Pays de Gex', 
#              width=800, height=800, tools=['hover', 'reset', 'wheel_zoom', 'pan'])
#     # définition de la ColumnDataSource
#     source = ColumnDataSource(dataplot)
#     mapper = linear_cmap('Type', palette,2000.,8000.)    
#     # regardez comment spécifier les colonnes à utiliser
#     # pour x et y, et comment déclarer comme source 
#     # la ColumnDataSource : 
#     center = p.circle('longitude', 'latitude', size=6, alpha=0.6, 
#                       color="blue", source=source)
#     show(p)
#     return p

# %% [markdown]
# # Plot sur une map clean et afficher les points dans le temps

# %%
import pandas as pd
import matplotlib.pyplot as plt
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %%
# street_map = gpd.read_file("ppoly_imap_baco.shp")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-110-f294d8e34d78> in <module>
# ----> 1 street_map = gpd.read_file("ppoly_imap_baco.shp")
#
# ~\anaconda3\envs\DataScience\lib\site-packages\geopandas\io\file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     202
#     203             return GeoDataFrame.from_features(
# --> 204                 f_filt, crs=crs, columns=columns + ["geometry"]
#     205             )
#     206
#
# ~\anaconda3\envs\DataScience\lib\site-packages\geopandas\geodataframe.py in from_features(cls, features, crs, columns)
#     585             row.update(feature["properties"])
#     586             rows.append(row)
# --> 587         return GeoDataFrame(rows, columns=columns, crs=crs)
#     588
#     589     @classmethod
#
# ~\anaconda3\envs\DataScience\lib\site-packages\geopandas\geodataframe.py in __init__(self, geometry, crs, *args, **kwargs)
#     103     def __init__(self, *args, geometry=None, crs=None, **kwargs):
#     104         with compat.ignore_shapely2_warnings():
# --> 105             super(GeoDataFrame, self).__init__(*args, **kwargs)
#     106
#     107         # need to set this before calling self['geometry'], because
#
# ~\anaconda3\envs\DataScience\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     519                             index = ibase.default_index(len(data))
#     520
# --> 521                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     522                 else:
#     523                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#
# ~\anaconda3\envs\DataScience\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      81
#      82         # don't force copy because getting jammed in an ndarray anyway
# ---> 83         arrays = _homogenize(arrays, index, dtype)
#      84
#      85         columns = ensure_index(columns)
#
# ~\anaconda3\envs\DataScience\lib\site-packages\pandas\core\internals\construction.py in _homogenize(data, index, dtype)
#     350                 val = lib.fast_multiget(val, oindex._values, default=np.nan)
#     351             val = sanitize_array(
# --> 352                 val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     353             )
#     354
#
# ~\anaconda3\envs\DataScience\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     511
#     512         if is_object_dtype(subarr.dtype) and not is_object_dtype(dtype):
# --> 513             inferred = lib.infer_dtype(subarr, skipna=False)
#     514             if inferred in {"interval", "period"}:
#     515                 subarr = array(subarr)
#
# pandas\_libs\lib.pyx in pandas._libs.lib.infer_dtype()
#
# MemoryError: Unable to allocate 2.44 MiB for an array with shape (319185,) and data type object

# %%
# fig,ax = plt.subplots(figsize = (15,15))
# street_map.plot(ax = ax)
# Out:
# <AxesSubplot:>

# %%
# df = dataplot

# %%
# df.Type.unique()
# Out:
# array(['NFS', 'SIS'], dtype=object)

# %%
# crs = {'init': 'epsg:4326'}
# df.head()
# Out:
#   Type                                            Geocode         DateAndTime  \
# 1  NFS  2000 Hoffman St.\nBaltimore 21213\n(39.3066183... 2013-01-10 10:40:00
# 2  NFS  3200 Brendan Ave\nBaltimore 21213\n(39.3222040... 2013-12-18 18:26:00
# 3  NFS  11610 Citrine Ct\nGlendale 20769\n(38.95854285... 2013-02-20 23:59:00
# 4  NFS  214 Green St\nFruitland 21826\n(38.31945272500... 2013-10-13 01:00:00
# 5  NFS  1723 Hollins St\nBaltimore 21223\n(39.28726344... 2013-05-23 22:22:00
#
#     latitude  longitude
# 1  39.306618 -76.589912
# 2  39.322204 -76.569603
# 3  38.958543 -76.804369
# 4  38.319453 -75.618947
# 5  39.287263 -76.644599

# %%
# geometry = [Point(xy) for xy in zip(df["longitude"], df["latitude"])]

# %%
# geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x20dfa67da48>,
#  <shapely.geometry.point.Point at 0x20df964d988>,
#  <shapely.geometry.point.Point at 0x20df964db08>]

# %%
# geo_df = gpd.GeoDataFrame(df, crs = crs, geometry = geometry)
# Out:
# C:\Users\ADDNOTHIING\anaconda3\envs\DataScience\lib\site-packages\pyproj\crs\crs.py:68: FutureWarning:
#
# '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6

# %%
# geo_df
# Out:
#     Type                                            Geocode  \
# 1    NFS  2000 Hoffman St.\nBaltimore 21213\n(39.3066183...
# 2    NFS  3200 Brendan Ave\nBaltimore 21213\n(39.3222040...
# 3    NFS  11610 Citrine Ct\nGlendale 20769\n(38.95854285...
# 4    NFS  214 Green St\nFruitland 21826\n(38.31945272500...
# 5    NFS  1723 Hollins St\nBaltimore 21223\n(39.28726344...
# ..   ...                                                ...
# 590  NFS  3224 Belmont Ave\nBaltimore 21216\n(39.3024966...
# 591  NFS  3500 Leverton Ave\nBaltimore 21224\n(39.291848...
# 592  NFS  1600 Northgate Rd\nBaltimore 21218\n(39.345078...
# 593  NFS  400 N. Robinson St.\nBaltimore 21224\n(39.2960...
# 594  NFS  4506 Westchester Ave\nBaltimore 21216\n(39.318...
#
#             DateAndTime   latitude  longitude                    geometry
# 1   2013-01-10 10:40:00  39.306618 -76.589912  POINT (-76.58991 39.30662)
# 2   2013-12-18 18:26:00  39.322204 -76.569603  POINT (-76.56960 39.32220)
# 3   2013-02-20 23:59:00  38.958543 -76.804369  POINT (-76.80437 38.95854)
# 4   2013-10-13 01:00:00  38.319453 -75.618947  POINT (-75.61895 38.31945)
# 5   2013-05-23 22:22:00  39.287263 -76.644599  POINT (-76.64460 39.28726)
# ..                  ...        ...        ...                         ...
# 590 2013-12-04 22:30:00  39.302497 -76.671323  POINT (-76.67132 39.30250)
# 591 2013-12-05 21:37:00  39.291848 -76.568418  POINT (-76.56842 39.29185)
# 592 2013-10-17 23:11:00  39.345078 -76.589210  POINT (-76.58921 39.34508)
# 593 2013-04-18 20:55:00  39.296098 -76.572945  POINT (-76.57295 39.29610)
# 594 2013-12-17 21:49:00  39.318215 -76.690292  POINT (-76.69029 39.31821)
#
# [594 rows x 6 columns]

# %%
# fig,ax = plt.subplots(figsize = (15,15))
# street_map.plot(ax = ax, alpha = 0.4)
# geo_df[geo_df["Type"] == "NFS"].plot(ax = ax, markersize = 20, color = "blue", marker = "o", label = "NFS")
# geo_df[geo_df["Type"] == "SIS"].plot(ax = ax, markersize = 20, color = "red", marker = "^", label = "SIS")
# plt.legend(prop={'size': 15})

# %%
# geo_df[geo_df["Type"] == "SIS"]
# Out:
#     Type                                            Geocode  \
# 10   SIS  27331 Birchwood Ct\nMechanicsville 20659\n(38....
# 16   SIS  3615 Kempsford Field\nWaldorf 20602\n(38.60749...
# 26   SIS  3220 Caraway Dr\nHuntingtown 20639\n(38.604641...
# 32   SIS  27594 Fairmount Rd\nWestover 21871\n(38.107058...
# 48   SIS  5084 Silver Hill Ct.\nSuitland 20747\n(38.8525...
# 91   SIS  29353 Fairmount Rd.\nWestover 21871\n(38.11479...
# 116  SIS  908 Karlson Ave.\nHyattsville 20783\n(38.96859...
# 121  SIS  6440 Central Ave\nSeat Pleasant 20743\n(38.887...
# 166  SIS  Hopkins Creek Ln. & Lanmark Ct.\nEssex 21221\n...
# 190  SIS  5621 61st Pl\nRiverdale 20737\n(38.95644102600...
#  [39.166891304000444, -77.20816234899968],
#  [39.30654802800046, -76.65254624699963],
#  [38.887135884000486, -76.90468624999966],
#  [39.29628811100048, -76.65503171999967],
#  [39.27424430600047, -76.50800332499966],
#  [39.29686310000045, -76.67478067699966],
#  [39.299827921000485, -76.58473215799967],
#  [39.04633744500046, -76.82627001599963],
#  [39.33934312100047, -76.70227066399963],
#  [39.234429831000455, -76.59796839299963],
#  [39.25212449600048, -76.64565143199968],
#  [39.30588892300045, -76.67079608699964],
#  [39.65875230100045, -75.79884301599964],
#  [39.29470833300047, -76.57479142299968],
#  [38.92634714500048, -76.86224491099966],
#  [39.38301344900049, -76.81996127199966],
#  [38.94654528400048, -76.96950853399966],
#  [39.30345127300046, -76.63899964599966],
#  [38.34352850200048, -75.59510068299966],
#  [39.305457970000475, -76.59485610599967],
#  [39.32279405000048, -76.56428376499963],
#  [39.35038082800048, -76.67120629899966],
#  [38.838428846000454, -76.92153668599963],
#  [39.27798233800047, -76.54285449599968],
#  [39.30249660600049, -76.67132267999966],
#  [39.291848092000464, -76.56841794299964],
#  [39.345078028000444, -76.58920992599963],
#  [39.29609798400048, -76.57294546799966],
#  [39.31821496700047, -76.69029205499965]]

# %%
m = folium.Map(location=[lat_mean, long_mean])
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d1df1cf754964ef7adaa0c2e5d505f28%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d1df1cf754964ef7adaa0c2e5d505f28%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d1df1cf754964ef7adaa0c2e5d505f28%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d1df1cf754964ef7adaa0c2e5d505f28%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B39.17010484379845%2C%20-76.65680736293736%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
import folium.plugins 
from branca.element import Figure

location = dataplot[['latitude', 'longitude']]
locationlist = location.values.tolist()
x = dataplot[1:2].Type

# %%
x
# Out:
# 2    NFS
# Name: Type, dtype: object

# %%
fig2=Figure(width=550,height=350)
m2 = folium.Map(location=[lat_mean, long_mean])


marker_cluster = folium.plugins.MarkerCluster().add_to(m2)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point],popup = ,tooltip='FUCK YOU', icon=folium.Icon(color='darkblue', icon_color='white', icon='male', angle=0, prefix='fa')).add_to(marker_cluster)
    
fig2.add_child(m2)
folium.TileLayer('Stamen Terrain').add_to(m2)
folium.TileLayer('Stamen Toner').add_to(m2)
folium.TileLayer('Stamen Water Color').add_to(m2)
folium.TileLayer('cartodbpositron').add_to(m2)
folium.TileLayer('cartodbdark_matter').add_to(m2)
folium.LayerControl().add_to(m2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\DataScience\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-205b6fa7801d> in <module>
#       5 marker_cluster = folium.plugins.MarkerCluster().add_to(m2)
#       6 for point in range(0, len(locationlist)):
# ----> 7     folium.Marker(locationlist[point],popup = Typewesh['Type'][point],tooltip='FUCK YOU', icon=folium.Icon(color='darkblue', icon_color='white', icon='male', angle=0, prefix='fa')).add_to(marker_cluster)
#       8
#       9 fig2.add_child(m2)
#
# ~\anaconda3\envs\DataScience\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ~\anaconda3\envs\DataScience\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     987
#     988         # Similar to Index.get_value, but we do not fall back to positional
# --> 989         loc = self.index.get_loc(label)
#     990         return self.index._get_values_for_loc(self, loc, label)
#     991
#
# ~\anaconda3\envs\DataScience\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Type'

# %%
m2
# Out:
# <iframe src="about:blank" width="550" height="350"style="border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1e52cd88b0124b02b52b94c37954b63b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1e52cd88b0124b02b52b94c37954b63b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1e52cd88b0124b02b52b94c37954b63b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1e52cd88b0124b02 ...
